# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
books = pd.read_csv("Books.csv")
users = pd.read_csv("Users.csv")
ratings = pd.read_csv("Ratings.csv")

# %%
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
books.tail()
# Out:
#               ISBN                                         Book-Title  \
# 221730  0752509713                     Rat a Tat / Ragamuffin Mystery
# 221731  0373123949        The Deserving Mistress (Harlequin Presents)
# 221732  3462030205                                             Klick.
# 221733  3608875050  Der KÃ?Â¶nig auf Camelot, 2 Bde. Neuausgabe, B...
# 221734  0717135276            Get Lucky!: Make Your Own Opportunities
#
#                   Book-Author Year-Of-Publication                 Publisher  \
# 221730            Enid Blyton                1996       Parragon Publishing
# 221731        Carole Mortimer                2004                 Harlequin
# 221732          Sergej Bolmat                2001  Kiepenheuer &amp; Witsch
# 221733  Terence Hanbury White                1996               Klett-Cotta
# 221734         Theresa Cheung                2003                   Newleaf
#
#                                               Image-URL-S  \
# ...

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
users.tail()
# Out:
#         User-ID                            Location   Age
# 278853   278854               portland, oregon, usa   NaN
# 278854   278855  tacoma, washington, united kingdom  50.0
# 278855   278856           brampton, ontario, canada   NaN
# 278856   278857           knoxville, tennessee, usa   NaN
# 278857   278858                dublin, n/a, ireland   NaN

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
ratings.tail()
# Out:
#          User-ID         ISBN  Book-Rating
# 1149775   276704   1563526298            9
# 1149776   276706   0679447156            0
# 1149777   276709   0515107662           10
# 1149778   276721   0590442449           10
# 1149779   276723  05162443314            8

# %%
books.shape
# Out:
# (221735, 8)

# %%
users.shape
# Out:
# (278858, 3)

# %%
ratings.shape
# Out:
# (1149780, 3)

# %%
books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            2
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            1
# Image-URL-L            4
# dtype: int64

# %%
users.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
ratings.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
books.dtypes
# Out:
# ISBN                   object
# Book-Title             object
# Book-Author            object
# Year-Of-Publication    object
# Publisher              object
# Image-URL-S            object
# Image-URL-M            object
# Image-URL-L            object
# dtype: object

# %%
users.dtypes
# Out:
# User-ID       int64
# Location     object
# Age         float64
# dtype: object

# %%
ratings.dtypes
# Out:
# User-ID         int64
# ISBN           object
# Book-Rating     int64
# dtype: object

# %%
books.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 221730    False
# 221731    False
# 221732    False
# 221733    False
# 221734    False
# Length: 221735, dtype: bool

# %%
users.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 278853    False
# 278854    False
# 278855    False
# 278856    False
# 278857    False
# Length: 278858, dtype: bool

# %%
ratings.duplicated()
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1149775    False
# 1149776    False
# 1149777    False
# 1149778    False
# 1149779    False
# Length: 1149780, dtype: bool

# %%
books['Book-Title'].unique()
# Out:
# array(['Classical Mythology', 'Clara Callan', 'Decision in Normandy', ...,
#        'Klick.',
#        'Der KÃ?Â¶nig auf Camelot, 2 Bde. Neuausgabe, Bd.2, Der miÃ?Â?ratene Ritter',
#        'Get Lucky!: Make Your Own Opportunities'], dtype=object)

# %%
users['Location'].unique()
# Out:
# array(['nyc, new york, usa', 'stockton, california, usa',
#        'moscow, yukon territory, russia', ...,
#        'sergnano, lombardia, italy', 'stranraer, n/a, united kingdom',
#        'tacoma, washington, united kingdom'], dtype=object)

# %%
ratings['Book-Rating'].unique()
# Out:
# array([ 0,  5,  3,  6,  8,  7, 10,  9,  4,  1,  2])

# %%
plt.figure
plt.title('Rating Counts')
sns.countplot(x = 'Book-Rating', data = ratings);

# %%
ratings_with_name = ratings.merge(books,on='ISBN')

# %%
ratings_with_name.shape
# Out:
# (975960, 10)

# %%
num_ratings=ratings_with_name.groupby('Book-Title').count()['Book-Rating'].reset_index()

# %%
num_ratings.shape
# Out:
# (198333, 2)

# %%
num_ratings.rename(columns={'Book-Rating':'Number Rating'}, inplace=True)

# %%
pd.to_numeric
# Out:
# <function pandas.core.tools.numeric.to_numeric(arg, errors: 'DateTimeErrorChoices' = 'raise', downcast: "Literal['integer', 'signed', 'unsigned', 'float'] | None" = None, dtype_backend: 'DtypeBackend | lib.NoDefault' = <no_default>)>

# %%
errors='coerce'

# %%
x = ratings_with_name.groupby('User-ID').count()['Book-Rating']

# %% [markdown]
# **Colaborative filtering**

# %%
x = ratings_with_name.groupby('User-ID').count()['Book-Rating']>200

# %%
users_with_ratings = x[x].index

# %%
filtered_rating = ratings_with_name[ratings_with_name['User-ID'].isin(users_with_ratings)]

# %%
y = filtered_rating.groupby('Book-Title').count()['Book-Rating']>=50
famous_books = y[y].index

# %%
final_ratings = filtered_rating[filtered_rating['Book-Title'].isin(famous_books)]

# %%
final_ratings.drop_duplicates()
# Out:
#         User-ID        ISBN  Book-Rating              Book-Title  \
# 61       278418  0446520802            0            The Notebook
# 63         3363  0446520802            0            The Notebook
# 64         7158  0446520802           10            The Notebook
# 67        11676  0446520802           10            The Notebook
# 72        23768  0446520802            6            The Notebook
# ...         ...         ...          ...                     ...
# 971745   266865  0531001725           10  The Catcher in the Rye
# 972861   269566  0670809381            0                  Echoes
# 973684   271284  0440910927            0           The Rainmaker
# 973976   271705  B0001PIOX4            0          Fahrenheit 451
# 975705   275970  1586210661            9  Me Talk Pretty One Day
#
#                   Book-Author Year-Of-Publication                Publisher  \
# 61            Nicholas Sparks                1996             Warner Books
# ...

# %%
pt = final_ratings.pivot_table(index='Book-Title',columns='User-ID',values='Book-Rating')

# %%
pt
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN    10.0     NaN
# 4 Blondes                                              NaN     NaN     NaN
# A Bend in the Road                                     0.0     NaN     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# ...

# %%
pt.fillna(0,inplace=True)

# %%
pt
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity_scores = cosine_similarity(pt)

# %%
similarity_scores.shape
# Out:
# (675, 675)

# %%
def recommend(book_name):
  index = np.where(pt.index==book_name)[0][0]
  similar_items = sorted(list(enumerate(similarity_scores[index])),key=lambda x:x[1],reverse=True)[1:5]
  data = []
  for i in similar_items:
    item = []
    temp_df = books[books['Book-Title'] == pt.index[i[0]]]
    item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Title'].values))
    item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Author'].values))
    item.extend(list(temp_df.drop_duplicates('Book-Title')['Image-URL-M'].values))
    data.append(item)
    return data

# %%
def recommend(book_name):
    index = np.where(pt.index==book_name)[0][0]
    similar_items = sorted(list(enumerate(similarity_scores[index])),key=lambda x:x[1],reverse=True)[1:5] # Fixed indentation here

    data = []
    for i in similar_items:
        item = []
        temp_df = books[books['Book-Title'] == pt.index[i[0]]]
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Title'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Author'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Image-URL-M'].values))

        data.append(item)

    return data

# %%
recommend('1984')
# Out:
# [["The Handmaid's Tale",
#   'Margaret Atwood',
#   'http://images.amazon.com/images/P/0449212602.01.MZZZZZZZ.jpg'],
#  ['Animal Farm',
#   'George Orwell',
#   'http://images.amazon.com/images/P/0451526341.01.MZZZZZZZ.jpg'],
#  ['The Vampire Lestat (Vampire Chronicles, Book II)',
#   'ANNE RICE',
#   'http://images.amazon.com/images/P/0345313860.01.MZZZZZZZ.jpg'],
#  ['Brave New World',
#   'Aldous Huxley',
#   'http://images.amazon.com/images/P/0060809833.01.MZZZZZZZ.jpg']]

# %%
pt.index[545]
# Out:
# 'The Lovely Bones: A Novel'

# %%
import pickle
pickle.dump(popular_df,open('popular.pkl','wb'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-290-5466dfa13903> in <cell line: 2>()
#       1 import pickle
# ----> 2 pickle.dump(popular_df,open('popular.pkl','wb'))
#
# NameError: name 'popular_df' is not defined
